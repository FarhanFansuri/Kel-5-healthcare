# %% [markdown]
# <a href="https://colab.research.google.com/github/FarhanFansuri/Kel-5-healthcare/blob/main/Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table of Content

# %% [markdown]
# # Summary

# %% [markdown]
# # Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # Get Data

# %%
url = 'https://raw.githubusercontent.com/FarhanFansuri/Kel-5-healthcare/main/Dataset/Medicine_Details.csv/Medicine_Details.csv'
df = pd.read_csv(url)

# %% [markdown]
# * pd.read_csv('Medicine_Details.csv'): Ini adalah panggilan
# fungsi dari Pandas untuk membaca sebuah file CSV. Fungsi ini mengambil satu argumen, yaitu string yang merupakan path (alamat) ke file CSV yang ingin dibaca, dalam hal ini "Medicine_Details.csv".
# * df = ...: Ini adalah cara kita menangkap hasil pembacaan file CSV ke dalam sebuah variabel yang dinamakan df. Biasanya, dalam konteks penggunaan Pandas, dataframe sering kali disebut df sebagai singkatan dari "dataframe".

# %%
df.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                                Bevacizumab (400mg)
# 1    Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 2                               Azithromycin (500mg)
# 3  Ambroxol (30mg/5ml) + Levosalbutamol (1mg/5ml)...
# 4                                 Ranitidine (150mg)
#
#                                                 Uses  \
# 0   Cancer of colon and rectum Non-small cell lun...
# 1                  Treatment of Bacterial infections
# 2                  Treatment of Bacterial infections
# 3                      Treatment of Cough with mucus
# 4  Treatment of Gastroesophageal reflux disease (...
#
#                                         Side_effects  \
# 0  Rectal bleeding Taste change Headache Noseblee...
# ...

# %% [markdown]
# * df: Ini adalah nama dataframe yang telah Anda buat sebelumnya dengan membaca file CSV menggunakan Pandas.
# * .head(): Ini adalah metode Pandas yang digunakan untuk mengambil beberapa baris pertama dari dataframe. Secara default, metode ini mengembalikan 5 baris pertama, tetapi Anda juga dapat memberikan parameter, misalnya df.head(10) akan mengembalikan 10 baris pertama.

# %%
df.tail()
# Out:
#                    Medicine Name  \
# 11820  Zilarta-CT 40/6.25 Tablet
# 11821              Zipcoz Tablet
# 11822        Zestasil 100 Tablet
# 11823            Zedruff Shampoo
# 11824            Zedruff Shampoo
#
#                                              Composition  \
# 11820  Azilsartan medoxomil (40mg) + Chlorthalidone (...
# 11821  Chromium Picolinate (100mcg) + D-Chiro Inosito...
# 11822                                 Sildenafil (100mg)
# 11823   Ketoconazole (2% w/v) + Zinc pyrithione (1% w/v)
# 11824   Ketoconazole (2% w/v) + Zinc pyrithione (1% w/v)
#
#                                       Uses  \
# 11820   Hypertension (high blood pressure)
# 11821   Polycystic ovarian syndrome (PCOS)
# 11822    Treatment of Erectile dysfunction
# 11823                Treatment of Dandruff
# 11824                Treatment of Dandruff
#
#                                             Side_effects  \
# 11820  Dizziness Tiredness Decreased potassium level ...
# ...

# %% [markdown]
# * df: Ini adalah nama dataframe yang telah Anda buat sebelumnya dengan membaca file CSV menggunakan Pandas.
# * .tail(): Ini adalah metode Pandas yang digunakan untuk mengambil beberapa baris terakhir dari dataframe. Secara default, metode ini mengembalikan 5 baris terakhir, tetapi Anda juga dapat memberikan parameter, misalnya df.tail(10) akan mengembalikan 10 baris terakhir.

# %% [markdown]
# # Cleaning Data

# %%
df.isnull().sum()
# Out:
# Medicine Name         0
# Composition           0
# Uses                  0
# Side_effects          0
# Image URL             0
# Manufacturer          0
# Excellent Review %    0
# Average Review %      0
# Poor Review %         0
# dtype: int64

# %% [markdown]
# * df: Ini adalah nama dataframe yang telah Anda buat sebelumnya dengan membaca file CSV menggunakan Pandas.
# * .isnull(): Ini adalah metode Pandas yang menghasilkan dataframe boolean yang menunjukkan di mana nilai-nilai dalam dataframe df adalah null (True) atau bukan (False).
# * .sum(): Ini adalah metode Pandas yang digunakan untuk menjumlahkan nilai True dalam setiap kolom. Karena nilai True dianggap sebagai 1 dan nilai False dianggap sebagai 0 ketika menjumlahkan, hasil dari .sum() adalah jumlah nilai yang hilang dalam setiap kolom.

# %%
df.duplicated().sum()
# Out:
# 84

# %% [markdown]
# * df: Ini adalah nama dataframe yang telah Anda buat sebelumnya dengan membaca file CSV menggunakan Pandas.
# * .duplicated(): Ini adalah metode Pandas yang menghasilkan dataframe boolean yang menunjukkan di mana baris-baris dalam dataframe df adalah duplikat (True) atau bukan (False).
# * .sum(): Ini adalah metode Pandas yang digunakan untuk menjumlahkan nilai True dalam dataframe boolean. Karena nilai True dianggap sebagai 1 dan nilai False dianggap sebagai 0 ketika menjumlahkan, hasil dari .sum() adalah jumlah baris yang terduplikat dalam dataframe.
#
#
# Fungsi df.duplicated().sum() digunakan untuk menghitung jumlah baris yang terduplikat dalam dataframe df. Ini berguna untuk mengetahui apakah terdapat baris yang sama persis (duplikat) dalam dataframe

# %%
clean_df = df.drop_duplicates()

# %%
clean_df.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                                Bevacizumab (400mg)
# 1    Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 2                               Azithromycin (500mg)
# 3  Ambroxol (30mg/5ml) + Levosalbutamol (1mg/5ml)...
# 4                                 Ranitidine (150mg)
#
#                                                 Uses  \
# 0   Cancer of colon and rectum Non-small cell lun...
# 1                  Treatment of Bacterial infections
# 2                  Treatment of Bacterial infections
# 3                      Treatment of Cough with mucus
# 4  Treatment of Gastroesophageal reflux disease (...
#
#                                         Side_effects  \
# 0  Rectal bleeding Taste change Headache Noseblee...
# ...

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
df.shape
# Out:
# (11825, 9)

# %%
df.describe()
# Out:
#        Excellent Review %  Average Review %  Poor Review %
# count        11825.000000      11825.000000   11825.000000
# mean            38.516025         35.756364      25.727611
# std             25.225343         18.268134      23.991985
# min              0.000000          0.000000       0.000000
# 25%             22.000000         27.000000       0.000000
# 50%             34.000000         35.000000      22.000000
# 75%             51.000000         47.000000      35.000000
# max            100.000000         88.000000     100.000000

# %% [markdown]
# * df: Ini adalah nama dataframe yang telah Anda buat sebelumnya dengan membaca file CSV menggunakan Pandas.
# * .describe(): Ini adalah metode Pandas yang digunakan untuk menghasilkan ringkasan statistik deskriptif dari dataframe. Metode ini hanya memberikan statistik untuk kolom-kolom numerik dalam dataframe, dan tidak termasuk kolom-kolom non-numerik.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11825 entries, 0 to 11824
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Medicine Name       11825 non-null  object
#  1   Composition         11825 non-null  object
#  2   Uses                11825 non-null  object
#  3   Side_effects        11825 non-null  object
#  4   Image URL           11825 non-null  object
#  5   Manufacturer        11825 non-null  object
#  6   Excellent Review %  11825 non-null  int64
#  7   Average Review %    11825 non-null  int64
#  8   Poor Review %       11825 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 831.6+ KB

# %% [markdown]
# * df: Ini adalah nama dataframe yang telah Anda buat sebelumnya dengan membaca file CSV menggunakan Pandas.
# * .info(): Ini adalah metode Pandas yang memberikan informasi lengkap tentang dataframe. Metode ini memberikan ringkasan tentang jumlah baris dan kolom, serta informasi tentang setiap kolom, seperti nama kolom, tipe data kolom, dan jumlah nilai non-null yang ada dalam setiap kolom.

# %%
df.columns
# Out:
# Index(['Medicine Name', 'Composition', 'Uses', 'Side_effects', 'Image URL',
#        'Manufacturer', 'Excellent Review %', 'Average Review %',
#        'Poor Review %'],
#       dtype='object')

# %% [markdown]
# Fungsi df.columns digunakan untuk mengakses daftar nama kolom yang ada dalam dataframe df. Ini memberikan daftar kolom yang tersedia dalam dataframe sehingga Anda dapat dengan mudah merujuk ke kolom-kolom tersebut saat melakukan manipulasi data atau analisis.

# %%
# Menghitung nilai frekuensi dari setiap komposisi
nilai_frekuensi_komposisi = clean_df['Composition'].value_counts()

# Tampilkan nilai frekuensi
nilai_frekuensi_komposisi
# Out:
# Luliconazole (1% w/w)                                                                                   98
# Levocetirizine (5mg) + Montelukast (10mg)                                                               76
# Ketoconazole (2% w/w)                                                                                   61
# Domperidone (30mg) + Rabeprazole (20mg)                                                                 59
# Itraconazole (100mg)                                                                                    53
#                                                                                                         ..
# Digoxin (0.25mg)                                                                                         1
# Sulphacetamide (20% w/v)                                                                                 1
# Furosemide (10mg/ml)                                                                                     1
# ...

# %%
# Ambil indeks nama komposisi dari value counts
nama_komposisi = nilai_frekuensi_komposisi.index.tolist()

# Ambil 30 nama komposisi pertama
nama_komposisi = nama_komposisi[:30]

# Tampilkan daftar 30 nama komposisi
nama_komposisi
# Out:
# ['Luliconazole (1% w/w)',
#  'Levocetirizine (5mg) + Montelukast (10mg)',
#  'Ketoconazole (2% w/w)',
#  'Domperidone (30mg) + Rabeprazole (20mg)',
#  'Itraconazole (100mg)',
#  'Telmisartan (40mg)',
#  'Itraconazole (200mg)',
#  'Domperidone (30mg) + Pantoprazole (40mg)',
#  'Telmisartan (40mg) + Amlodipine (5mg)',
#  'Glimepiride (2mg) + Metformin (500mg)',
#  'Metformin (500mg)',
#  'Minoxidil (5% w/v)',
#  'Ketoconazole (2% w/v) + Zinc pyrithione (1% w/v)',
#  'Amoxycillin  (500mg) +  Clavulanic Acid (125mg)',
#  'Rabeprazole (20mg)',
#  'Levocetirizine (5mg)',
#  'Glimepiride (2mg) + Metformin (500mg) + Pioglitazone (15mg)',
#  'Teneligliptin (20mg)',
#  'Methylcobalamin (750mcg) + Pregabalin (75mg)',
#  'Carboxymethylcellulose (0.5% w/v)',
#  'Terbinafine (1% w/w)',
#  'Glimepiride (2mg) + Metformin (500mg) + Voglibose (0.2mg)',
#  'Pantoprazole (40mg)',
#  'Montelukast (10mg) + Fexofenadine (120mg)',
#  'Metformin (500mg) + Teneligliptin (20mg)',
# ...

# %%
# Generate frekuensi untuk setiap nama komposisi
frekuensi = [clean_df['Composition'].value_counts()[nama] for nama in nama_komposisi]

# Buat plot bar dengan kustomisasi
plt.figure(figsize=(10, 8))
plt.barh(nama_komposisi, frekuensi, color='skyblue', edgecolor='black')

plt.xlabel('Frekuensi')
plt.ylabel('Nama Komposisi')
plt.title('Top 30 Frekuensi Komposisi')
plt.gca().invert_yaxis()  # Balikkan sumbu y untuk menampilkan yang paling sering di bagian atas

# Tambahkan nilai frekuensi sebagai teks pada batang
for i, v in enumerate(frekuensi):
    plt.text(v + 0.2, i, str(v), color='black', va='center')

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

# Tampilkan plot
plt.show()

# %% [markdown]
# # Visualisasi

# %%
# Dapatkan nilai counts dari efek samping dan batasi hingga 10 teratas
efek_samping_counts = clean_df['Side_effects'].value_counts().head(10)

# Buat kamus untuk menyimpan obat-obatan untuk setiap efek samping
efek_samping_obat = {}

# Loop melalui efek samping unik dan kumpulkan obat yang terkait
for efek_samping in efek_samping_counts.index:
    # Filter DataFrame untuk setiap efek samping unik
    obat_untuk_efek_samping = clean_df.loc[clean_df['Side_effects'] == efek_samping, 'Medicine Name'].tolist()

    # Simpan daftar obat untuk efek samping dalam kamus
    efek_samping_obat[efek_samping] = obat_untuk_efek_samping

# Buat grafik batang untuk 10 efek samping teratas dan jumlah kemunculannya dengan estetika yang ditingkatkan
plt.figure(figsize=(12, 8))
grafik_batang = efek_samping_counts.plot(kind='bar', color='skyblue', edgecolor='black')

# Menambahkan anotasi untuk setiap bar dengan format kustom
for i, jumlah in enumerate(efek_samping_counts):
    plt.text(i, jumlah + 1, f'{jumlah}', ha='center', va='bottom', fontsize=10)

# Gambar garis horizontal untuk jumlah rata-rata
jumlah_rata_rata = efek_samping_counts.mean()
plt.axhline(jumlah_rata_rata, color='red', linestyle='--', label=f'Rata-rata: {jumlah_rata_rata:.2f}')
plt.legend()

# Gambar garis horizontal untuk jumlah median
jumlah_median = efek_samping_counts.median()
plt.axhline(jumlah_median, color='green', linestyle="--", label=f'Median: {jumlah_median:.2f}')
plt.legend()

plt.title('Top 10 Kemunculan Efek Samping')
plt.xlabel('Efek Samping')
plt.ylabel('Jumlah')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-90-361b13d5c6d2>:38: UserWarning:
#
# Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.

# %% [markdown]
# Code tersebut dilakukan untuk memvisualisasikan data terkait dengan efek samping dari obat-obatan. Penjelasan code dapat disimak dibawah ini:
# * Pertama, hitung jumlah kemunculan (counts) dari setiap efek samping dalam DataFrame clean_df menggunakan method value_counts(). Kemudian, mengambil 10 nilai teratas menggunakan method head(10). Hasilnya disimpan dalam variabel side_effects_counts.
# * Selanjutnya, membuat dictionary side_effects_medicines yang akan menyimpan efek samping sebagai kunci (key) dan daftar obat-obatan yang terkait dengan efek samping tersebut sebagai nilai (value). Lakukan iterasi melalui indeks efek samping dari side_effects_counts, dan untuk setiap efek samping, Lalu filter DataFrame clean_df untuk mendapatkan daftar obat-obatan yang terkait dengan efek samping tersebut. Daftar obat-obatan ini kemudian disimpan dalam dictionary side_effects_medicines dengan menggunakan efek samping sebagai kunci.
# * Selanjutnya, membuat plot bar menggunakan method plot() dari pandas. Tentukan jenis plot sebagai kind='bar' dan memberikan warna serta garis tepi untuk batang bar.
# * Tambahkan label untuk setiap batang bar yang menunjukkan jumlah kemunculan efek samping menggunakan plt.text().
# * Tambahkan garis horizontal yang menunjukkan rata-rata (mean_count) dan median (median_count) dari jumlah kemunculan efek samping. Garis-garis ini digambar menggunakan plt.axhline().
# * Berikan judul (plt.title()), label sumbu x dan y (plt.xlabel() dan plt.ylabel()), serta merotasi label sumbu x (plt.xticks(rotation=45, ha='right')). Anda juga menambahkan grid pada sumbu y menggunakan plt.grid().
# * Tampilkan plot menggunakan plt.show().
#
# Jadi secara keseluruhan, kode tersebut digunakan untuk mengeksplorasi dan memvisualisasikan data terkait dengan efek samping dari obat-obatan dalam DataFrame clean_df.

# %%
# Dapatkan nilai counts dari penggunaan (Uses)
penggunaan_counts = clean_df['Uses'].value_counts().head(10)

# Buat kamus untuk menyimpan obat-obatan untuk setiap penggunaan
penggunaan_obat = {}

# Loop melalui penggunaan unik dan kumpulkan obat yang terkait
for penggunaan, hitungan in penggunaan_counts.items():
    # Filter DataFrame untuk setiap penggunaan unik
    obat_untuk_penggunaan = clean_df.loc[clean_df['Uses'] == penggunaan, 'Medicine Name'].tolist()

    # Simpan daftar obat untuk penggunaan dalam kamus
    penggunaan_obat[penggunaan] = obat_untuk_penggunaan

# Tampilkan hanya 10 penggunaan pertama dan obat-obat yang terkait
for idx, (penggunaan, obat) in enumerate(penggunaan_obat.items()):
    if idx >= 10:
        break  # Keluar dari loop setelah mencetak 10 kemunculan

    print(f"Penggunaan: {penggunaan}")
    print(f"Jumlah Kemunculan: {penggunaan_counts[penggunaan]}")
    print(f"Obat-obatan: {obat}")
    print("------------------------")
# Out:
# Penggunaan: Treatment of Type 2 diabetes mellitus
# Jumlah Kemunculan: 904
# ...

# %%
# Ambil 10 penggunaan teratas
top_10_penggunaan = penggunaan_counts.head(10)

# Hitung nilai median dan mean
nilai_median = top_10_penggunaan.median()
nilai_rata_rata = top_10_penggunaan.mean()

# Buat grafik batang untuk 10 penggunaan teratas dan jumlah kemunculannya
plt.figure(figsize=(13, 10))
grafik_batang = top_10_penggunaan.plot(kind='bar', color='skyblue', edgecolor='black')

# Menambahkan anotasi untuk setiap bar
for i, jumlah in enumerate(top_10_penggunaan):
    plt.text(i, jumlah + 1, str(jumlah), ha='center', va='bottom', fontsize=10)

# Plot garis median dengan anotasi
plt.axhline(nilai_median, color='red', linestyle='--', linewidth=1.5, label=f'Median: {nilai_median:.2f}')
plt.text(len(top_10_penggunaan) - 1, nilai_median, f'Median: {nilai_median:.2f}', color='red', va='bottom', ha='right', fontsize=10)

# Plot garis mean dengan anotasi
plt.axhline(nilai_rata_rata, color='green', linestyle='-.', linewidth=1.5, label=f'Rata-rata: {nilai_rata_rata:.2f}')
plt.text(len(top_10_penggunaan) - 1, nilai_rata_rata, f'Rata-rata: {nilai_rata_rata:.2f}', color='green', va='bottom', ha='right', fontsize=10)

plt.title('Top 10 Kemunculan Penggunaan dan Obat-obatan Terkait', fontsize=14)
plt.xlabel('Penggunaan', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.ylim(0, top_10_penggunaan.max() * 1.1)
plt.legend(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Library yang digunakan yaitu Plotly
# Menghitung nilai frekuensi dari setiap komposisi
nilai_frekuensi_komposisi = clean_df['Composition'].value_counts()

# Membuat DataFrame dari nilai frekuensi komposisi
df_frekuensi = nilai_frekuensi_komposisi.reset_index()
df_frekuensi.columns = ['Komposisi', 'Frekuensi']

# Mengambil 30 komposisi teratas
top_10_komposisi = df_frekuensi.head(10)

# Membuat plot batang horizontal menggunakan Plotly Express
fig = px.bar(top_10_komposisi,
             x='Frekuensi',
             y='Komposisi',
             orientation='h',
             title='10 Frekuensi Komposisi Teratas',
             labels={'Frekuensi': 'Frekuensi', 'Komposisi': 'Komposisi'})

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
