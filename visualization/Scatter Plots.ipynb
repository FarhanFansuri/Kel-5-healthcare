# %% [markdown]
# ## Scatter Plots
# Leverage the coordinate plane to explore relationships between variables

# %% [markdown]
# ### Set Up The Notebook

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# ### Load and Examine The Data
# Kode yang diberikan berikut ini menunjukkan bagaimana cara membaca data dari file CSV (Comma-Separated Values) yang berisi informasi asuransi menggunakan pustaka Pandas di Python:

# %%
# Path of the file to read
insurance_filepath = "INPUT\\insurance.csv"

# Read the file into a variable insurance_data
insurance_data = pd.read_csv(insurance_filepath)

# %% [markdown]
# 1. insurance_filepath = "/content/insurance.csv": Baris pertama mendefinisikan variabel insurance_filepath dan menetapkan path ke file CSV yang ingin dibaca. Ganti "/content/insurance.csv" dengan path sebenarnya dari file CSV Anda yang berisi data asuransi.
#
# 2. insurance_data = pd.read_csv(insurance_filepath): Baris kedua menggunakan fungsi pd.read_csv dari pustaka Pandas untuk membaca data dari file CSV. Fungsi ini mengambil argumen:
#
# insurance_filepath: Path ke file CSV yang ingin dibaca.
#
#
# Setelah dieksekusi, kode ini akan menyimpan data yang dibaca dari file CSV ke dalam variable insurance_data sebagai DataFrame Pandas. DataFrame adalah struktur data tabular yang lazim digunakan untuk analisis data.

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# insurance_data.head() mengembalikan lima baris pertama dari DataFrame insurance_data secara default. Jadi, baris yang ditampilkan adalah baris pertama hingga baris kelima dari DataFrame tersebut.
#
# Jika Anda ingin menampilkan baris tertentu, Anda dapat menentukan jumlah baris yang ingin Anda lihat sebagai argumen dalam metode .head(). Misalnya, insurance_data.head(10) akan menampilkan sepuluh baris pertama dari DataFrame.

# %% [markdown]
# ### Scatter Plots
# Kode sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges']) menggunakan pustaka Seaborn untuk membuat scatter plot (plot pen散布 (san-pu) = sebar) yang memvisualisasikan hubungan antara Indeks Massa Tubuh (IMT) dan biaya asuransi dalam DataFrame insurance_data Anda.

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# Scatter plot di atas menunjukkan bahwa indeks massa tubuh (BMI) dan biaya asuransi memiliki korelasi positif, di mana pelanggan dengan BMI yang lebih tinggi cenderung membayar lebih banyak dalam biaya asuransi. Pola ini masuk akal, karena BMI yang tinggi umumnya berhubungan dengan risiko penyakit kronis yang lebih tinggi.
#
# Scatter Plot:
#
# sns.scatterplot adalah fungsi dari Seaborn yang digunakan untuk membuat scatter plot.
#
# x=insurance_data['bmi']: Ini menetapkan kolom IMT (jika ada) sebagai data untuk sumbu horizontal (x).
#
# y=insurance_data['charges']: Ini menetapkan kolom biaya (jika ada) sebagai data untuk sumbu vertikal (y).
#
# Kode sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges']) mengembangkan konsep scatter plot yang Anda lihat sebelumnya, tetapi dengan fitur tambahan.

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# Plot Regresi:
#
#     sns.regplot adalah fungsi dari Seaborn yang khusus dirancang untuk plot regresi.
#
#     Ia mewarisi fungsionalitas dari sns.scatterplot untuk membuat scatter plot antara IMT dan biaya (seperti sebelumnya).
#
#     Selain itu, fungsi ini menghitung garis regresi yang paling sesuai dengan titik data, bertujuan untuk menangkap tren keseluruhan dalam hubungan antara IMT dan biaya.

# %% [markdown]
# ### Color Coded Scatter Plots
# Kita dapat menggunakan plot sebar untuk menampilkan hubungan antara (bukan dua, tapi...) tiga variabel! Salah satu cara untuk melakukan ini adalah dengan memberi kode warna pada titik-titik tersebut.
#
# Kode sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker']) membuat scatter plot yang diberi warna berdasarkan variabel kategoris, untuk menunjukkan potensi perbedaan antar kelompok.

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# Scatter Plot dengan Pewarna (Hue):
#
#     sns.scatterplot adalah fungsi dasar untuk membuat scatter plot.
#
#     x=insurance_data['bmi'] dan y=insurance_data['charges'] menentukan data untuk sumbu x dan y (sama seperti sebelumnya).
#
#     hue=insurance_data['smoker'] memperkenalkan konsep baru. Ini menetapkan warna untuk setiap titik data berdasarkan nilai pada kolom 'smoker' (perokok). Hal ini memungkinkan Anda untuk melihat apakah ada tren atau perbedaan dalam hubungan antara IMT dan biaya tergantung pada apakah seseorang perokok atau bukan.
#
# Kode sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data) mengembangkan konsep scatter plot berwarna yang Anda lihat sebelumnya, tetapi selangkah lebih maju dengan menambahkan garis regresi.
#
# Garis yang berbeda menunjukkan korelasi antara BMI dan biaya asuransi bagi perokok dan non-perokok. Garis regresi untuk perokok memiliki kemiringan yang jauh lebih curam daripada garis untuk non-perokok. Ini menunjukkan bahwa hubungan antara BMI dan biaya asuransi lebih kuat bagi perokok, yang berarti perokok cenderung membayar lebih banyak dalam biaya asuransi dengan peningkatan BMI dibandingkan dengan non-perokok.
#
# Untuk lebih menekankan fakta ini, kita dapat menggunakan perintah sns.lmplot untuk menambahkan dua garis regresi, yang sesuai dengan perokok dan non-perokok. (Anda akan melihat bahwa garis regresi untuk perokok memiliki kemiringan yang jauh lebih curam, relatif terhadap garis untuk non-perokok!)

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)

# %% [markdown]
# Plot Model Linear:
#
#     sns.lmplot adalah fungsi dari Seaborn yang khusus dirancang untuk membuat visualisasi dengan garis regresi untuk data kategoris.
#
#     x="bmi" dan y="charges" menentukan data untuk sumbu x dan y (mirip dengan scatter plot).
#
#     hue="smoker" menetapkan warna untuk setiap titik data dan garis regresi berdasarkan nilai pada kolom 'smoker' (seperti scatter plot berwarna).
#
#     data=insurance_data menentukan DataFrame yang berisi data untuk plot.
#
# Kode sns.swarmplot(x=insurance_data['smoker'], y=insurance_data['charges']) menggunakan pustaka Seaborn untuk membuat jenis plot sebaran khusus yang disebut "swarm plot" (plot sebaran lebah).
#
# Biasanya, kita menggunakan scatter plot untuk menyoroti hubungan antara dua variabel kontinu (seperti "bmi" dan "charges"). Namun, kita dapat menyesuaikan desain scatter plot untuk menampilkan variabel kategori (seperti "smoker") pada salah satu sumbu utama. Kami akan merujuk pada jenis plot ini sebagai scatter plot kategorikal, dan kita membangunnya dengan perintah sns.swarmplot.

# %%
sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges'])
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Plot Sebaran Lebah (Swarm Plot):
#
#     sns.swarmplot adalah fungsi dari Seaborn yang dirancang untuk memvisualisasikan data kategoris.
#
#     x=insurance_data['smoker'] menetapkan kolom 'smoker' (kategoris) sebagai data untuk sumbu x.
#
#     y=insurance_data['charges'] menetapkan kolom biaya (numerik) sebagai data untuk sumbu y.
#
# Di antara hal lain, plot ini menunjukkan kepada kita bahwa:
#
# Secara rata-rata, non-perokok dikenakan biaya lebih sedikit daripada perokok.
# Pelanggan yang membayar paling banyak adalah perokok; sedangkan pelanggan yang membayar paling sedikit adalah non-perokok.
